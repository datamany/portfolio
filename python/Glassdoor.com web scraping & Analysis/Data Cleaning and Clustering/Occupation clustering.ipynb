# %%
import pandas as pd; import matplotlib.pyplot as plt

# %%
df = pd.read_csv('all_extracted_df_filtered.csv')

# %%
df['state'] = df['Location'].apply(lambda x: x.split(',')[1].strip() if len(x.split(','))>1 else  None)
df['Location'] = df['Location'].apply(lambda x: x.split(',')[0].strip())

# %%
df[['Location', 'state']]
# Out:
#          Location state
# 0         Atlanta    GA
# 1         Atlanta    GA
# 2         Atlanta    GA
# 3         Atlanta    GA
# 4         Atlanta    GA
# ...           ...   ...
# 40321  Washington    DC
# 40322  Washington    DC
# 40323  Washington    DC
# 40324  Washington    DC
# 40325  Washington    DC
#
# [40326 rows x 2 columns]

# %%
df.GDJobTitle.value_counts().head(20).sort_values(ascending = True).plot(kind = 'barh', figsize = (8,10))
plt.grid(axis = 'x')
plt.xticks( fontsize = '14')
plt.yticks(fontsize = '14')
plt.show()

# %%
## Location
df.Location.value_counts().head(20).sort_values(ascending = True).plot(kind = 'barh', figsize = (8,10))
plt.grid(axis = 'x')
plt.xticks( fontsize = '14')
plt.yticks(fontsize = '14')
plt.show()

# %%
df.state.value_counts().head(20).sort_values(ascending = False).plot(kind = 'bar', figsize = (20,4))
plt.grid(axis = 'y')
plt.xticks(rotation = '45', fontsize = '14')
plt.yticks(fontsize = '14')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40326 entries, 0 to 40325
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   job_id       40326 non-null  int64
#  1   jobTitle     40326 non-null  object
#  2   GDJobTitle   40326 non-null  object
#  3   Location     40326 non-null  object
#  4   CompanyName  40321 non-null  object
#  5   HqLocation   35106 non-null  object
#  6   CompanySize  35716 non-null  object
#  7   Industry     40324 non-null  object
#  8   Sector       35716 non-null  object
#  9   Star_rating  35716 non-null  float64
#  10  description  40326 non-null  object
#  11  state        39936 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 3.7+ MB
